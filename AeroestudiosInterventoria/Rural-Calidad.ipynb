# %% [markdown]
# # REPORTE INTERVENTORIA AEROESTUDIOS GNSS

# %% [markdown]
# # Rural Calidad

# %%
import os; import pandas as pd;import geopandas as gpd;import glob;import re;import numpy as np

# %%
#definir municipio 
mun="\\Sopetran"
fmun=r"D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios"
frev=fRev=r"D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Revisión"+mun
fmun=fmun+mun

# %% [markdown]
# ### *Estructura digital*

# %%
folder="\\Rural-Calidad"
path=fmun+folder
fRuCal=pd.DataFrame(os.listdir(path))
fRuCal
# Out:
#                          0
# 0    1. Archivo geografico
# 1    2. Hojas descriptivas
# 2    2.1 Hoja de ocupacion
# 3           3. Datos rinex
# 4         3.1 Datos crudos
# 5   4. Efemerides precisas
# 6   5. Reportes de calculo
# 7  6. Registro Fotografico
# 8           7. Coordenadas

# %% [markdown]
# ### *Verificación Shapefile*

# %%
#verificación Shapefile
fshp=fmun+folder+"\\1. Archivo geografico"

for filename in glob.iglob(fshp+"\\*.shp"):
    print(filename)
    shp=gpd.read_file(filename)
    name=filename.split('\\1. Archivo geografico\\')
    print("----------> "+name[1]+" puntos: "+str(shp.geometry.count()))
    puntos=shp[["NAME","ESTE","NORTE","Altura_Ort"]]; print(puntos)
# Out:
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\1. Archivo geografico\SOPETRAN_Rural_Calidad.shp
# ----------> SOPETRAN_Rural_Calidad.shp puntos: 40
#          NAME         ESTE        NORTE  Altura_Ort
# 0    CR-10810  4696550.505  2278912.365     701.465
# 1    CR-10811  4695328.885  2275790.047     700.670
# 2    CR-10813  4697207.995  2285563.405    1687.266
# 3    CR-10815  4698431.722  2282432.376    1482.367
# 4    CR-10816  4702052.339  2282322.255    1752.304
# 5    CR-10817  4704856.914  2279648.873    2150.878
# 6    CR-10818  4701149.399  2277424.264    1776.655
# 7    CR-10819  4700746.419  2283398.270    1701.938
# 8    CR-10820  4691010.494  2274091.050     508.677
# 9    CR-10821  4689320.377  2277946.335     514.612
# 10   CR-10823  4687864.732  2273812.959     475.587
# 11   CR-10824  4692767.872  2272002.366     650.453
# 12   CR-10825  4692427.901  2269893.464     578.508
# 13   CR-10826  4690316.508  2265957.666    1215.991
# 14   CR-10827  4696186.690  2280522.029     876.510
# 15   CR-10828  4690373.574  2278364.967     456.327
# 16   CR-10829  4702046.983  2281165.685    2123.101
# 17   CR-10830  4695051.330  2284137.857     888.410
# 18   CR-10831  4691681.855  2276022.060     488.854
# 19   CR-10832  4688608.508  2274820.073     482.265
# 20   CR-10833  4697859.494  2288542.002    2269.550
# 21   CR-10834  4696729.095  2286727.354    1968.248
# 22   CR-10835  4699357.702  2286435.296    1578.100
# 23   CR-10836  4693652.959  2273879.386     511.554
# 24   CR-10837  4698075.293  2276485.340     951.926
# 25   CR-10838  4692152.984  2268630.262     600.241
# 26   CR-10839  4699130.552  2279978.379    1523.044
# 27   CR-10840  4688461.940  2269886.321     475.651
# 28   CR-10841  4690382.803  2276410.021     487.633
# 29   CR-10842  4691875.987  2271945.343     543.431
# 30   CR-10844  4706310.367  2278949.887    2464.258
# 31   CR-10845  4696453.405  2282984.962    1170.608
# 32   CR-10846  4693445.722  2280746.406     552.643
# 33   CR-10847  4698803.082  2284732.787    1681.829
# 34  R-SOPT-01  4688311.841  2267469.412     469.302
# 35  R-SOPT-02  4693193.528  2270420.124     630.082
# 36  R-SOPT-03  4700470.754  2289586.135    2570.999
# 37  R-SOPT-04  4697610.986  2282049.581    1346.631
# 38  R-SOPT-05  4704014.301  2281927.645    2448.884
# 39  R-SOPT-06  4696891.166  2276691.196     816.980

# %% [markdown]
# ### *Verificación Hojas descriptivas*

# %%
#Verificación hojas descriptivas ---> comparación con puntos del Shapefile. Devuelve una matriz con los valores que no estan incluidos
hcampo=fmun+folder+"\\2. Hojas descriptivas"
print( "$~-----------> 2 Hojas descriptivas")
files_campo=os.listdir(hcampo)
df_filescampo=pd.DataFrame(files_campo)
Hojas_campo=[i.split('.')[0] for i in files_campo]
print(df_filescampo)
print("Hojas de Descripción:  -->"+str(len(files_campo)))
hone=[x for x in Hojas_campo if x not in puntos.values]
print("@@ COINCIDENCIA HOJAS DE DESCRIPCION @@")
print("@@ --->  Todas las descripciones Coinciden con Shp: "+str(shp.geometry.count())) if len(hone)==0 else print(hone)
# Out:
# $~-----------> 2 Hojas descriptivas
#                   0
# 0      CR-10810.jpg
# 1      CR-10811.jpg
# 2      CR-10813.jpg
# 3      CR-10815.jpg
# 4      CR-10816.jpg
# 5      CR-10817.jpg
# 6      CR-10818.jpg
# 7      CR-10819.jpg
# 8      CR-10820.jpg
# 9      CR-10821.jpg
# 10     CR-10823.jpg
# 11     CR-10824.jpg
# 12     CR-10825.jpg
# 13     CR-10826.jpg
# 14     CR-10827.jpg
# 15     CR-10828.jpg
# 16     CR-10829.jpg
# 17     CR-10830.jpg
# 18     CR-10831.jpg
# 19     CR-10832.jpg
# 20     CR-10833.jpg
# 21     CR-10834.jpg
# 22     CR-10835.jpg
# 23     CR-10836.jpg
# 24     CR-10837.jpg
# 25     CR-10838.jpg
# 26     CR-10839.jpg
# 27     CR-10840.jpg
# 28     CR-10841.jpg
# 29     CR-10842.jpg
# 30     CR-10844.jpg
# 31     CR-10845.jpg
# 32     CR-10846.jpg
# 33     CR-10847.jpg
# 34  Hojas_mejoradas
# 35    R-SOPT-01.jpg
# 36    R-SOPT-02.jpg
# 37    R-SOPT-03.jpg
# 38    R-SOPT-04.jpg
# 39    R-SOPT-05.jpg
# 40    R-SOPT-06.jpg
# Hojas de Descripción:  -->41
# @@ COINCIDENCIA HOJAS DE DESCRIPCION @@
# ['Hojas_mejoradas']

# %% [markdown]
# ## *Verificiación Hojas de Ocupación*

# %%
#Verificación Hojas de ocupación
hcampo1=fmun+folder+"\\2.1 Hoja de ocupacion"
##Base folder 

for base in glob.iglob(hcampo1+"\\**\\**.*",recursive=True):
    hcampo2=base.split("\\2.1 Hoja de ocupacion")
    print(hcampo2[1])
##Rover Folder
files_ocup=os.listdir(hcampo1+"\\Rover") # --> *set de Rover File
files_ocup0=[i.split('.')[0] for i in files_ocup]
print("Hojas de Ocupación:  -->"+str(len(files_ocup)))
hocu=[x for x in files_ocup0 if x not in puntos.values]
print("@@ COINCIDENCIA HOJAS DE OCUPACION @@")
if len(hocu)==0:
    print("@@ --->  Todas las descripciones Coinciden con Shp: "+str(shp.geometry.count())) 
else:
    print("@@ NO COINCIDEN TODAS LAS HOJAS DE OCUPACIÓN  ---->:"+str(len(hocu)))
    print(pd.DataFrame(hocu))
# Out:
# \Base\2023-03-12-071\05761004.jpg
# \Base\2023-03-13-072\05761004.jpg
# \Base\2023-03-14-073\05761004.jpg
# \Base\2023-03-15-074\05761004.jpg
# \Base\2023-03-16-075\05761004.jpg
# \Base\2023-03-17-076\05761004.jpg
# \Base\2023-03-18-077\05761004.jpg
# \Base\2023-03-20-079\05761004.jpg
# \Base\2023-03-21-080\05761004.jpg
# \Base\2023-03-22-081\05761004.jpg
# \Base\2023-03-23-082\05761004.jpg
# \Base\2023-03-24-083\05761004.jpg
# \Base\2023-03-25-084\05761004.jpg
# \Rover\CR-10810.jpg
# \Rover\CR-10811.jpg
# \Rover\CR-10813.jpg
# \Rover\CR-10815.jpg
# \Rover\CR-10816.jpg
# \Rover\CR-10817.jpg
# \Rover\CR-10818.jpg
# \Rover\CR-10819.jpg
# \Rover\CR-10820.jpg
# \Rover\CR-10821.jpg
# \Rover\CR-10823.jpg
# \Rover\CR-10824.jpg
# \Rover\CR-10825.jpg
# \Rover\CR-10826.jpg
# \Rover\CR-10827.jpg
# \Rover\CR-10828.jpg
# \Rover\CR-10829.jpg
# \Rover\CR-10830.jpg
# \Rover\CR-10831.jpg
# \Rover\CR-10832.jpg
# \Rover\CR-10833.jpg
# \Rover\CR-10834.jpg
# \Rover\CR-10835.jpg
# \Rover\CR-10836.jpg
# \Rover\CR-10837.jpg
# \Rover\CR-10838.jpg
# \Rover\CR-10839.jpg
# \Rover\CR-10840.jpg
# \Rover\CR-10841.jpg
# \Rover\CR-10842.jpg
# \Rover\CR-10844.jpg
# \Rover\CR-10845.jpg
# \Rover\CR-10846.jpg
# \Rover\CR-10847.jpg
# \Rover\R-SOPT-01.jpg
# \Rover\R-SOPT-02.jpg
# \Rover\R-SOPT-03.jpg
# \Rover\R-SOPT-04.jpg
# \Rover\R-SOPT-05.jpg
# \Rover\R-SOPT-06.jpg
# Hojas de Ocupación:  -->40
# @@ COINCIDENCIA HOJAS DE OCUPACION @@
# @@ --->  Todas las descripciones Coinciden con Shp: 40

# %% [markdown]
# ### *Verificación archivos Rinex y Raw data*

# %% [markdown]
# ##### *Rinex Data*

# %%
rinex=fmun+folder+"\\3. Datos rinex"
rinexdf=pd.DataFrame(os.listdir(rinex))
print("Carpetas Rinex");print(rinexdf)
listrinex=[]
for rinex1 in glob.iglob(rinex+"\\**\\**.*",recursive=True):
    lista0=rinex1.split("\\3. Datos rinex\\")

    lista0=str(lista0[1])
    listrinex.append(lista0)

listrinex=[i.split('\\') for i in listrinex]
rinex=pd.DataFrame(listrinex)
rinex

puntosunicos=rinex.iloc[:,2].unique()  
print("Puntos: "+str(len(puntosunicos)))
ptosunicos=pd.DataFrame(puntosunicos)
ptosunicos
# Out:
# Carpetas Rinex
#                  0
# 0   2023-03-13-072
# 1   2023-03-14-073
# 2   2023-03-15-074
# 3   2023-03-16-075
# 4   2023-03-17-076
# 5   2023-03-18-077
# 6   2023-03-20-079
# 7   2023-03-21-080
# 8   2023-03-22-081
# 9   2023-03-23-082
# 10  2023-03-25-084
# Puntos: 41
#             0
# 0    05761004
# 1    CR-10840
# 2   R-SOPT-01
# 3    CR-10811
# 4    CR-10820
# 5    CR-10821
# 6    CR-10823
# 7    CR-10832
# 8    CR-10841
# 9    CR-10824
# 10   CR-10825
# 11   CR-10837
# 12   CR-10838
# 13   CR-10842
# 14  R-SOPT-02
# 15  R-SOPT-06
# 16   CR-10810
# 17   CR-10826
# 18   CR-10827
# 19  R-SOPT-04
# 20   CR-10831
# 21   CR-10836
# 22  R-SOPT-03
# 23   CR-10813
# 24   CR-10833
# 25   CR-10834
# 26   CR-10835
# 27   CR-10847
# 28   CR-10830
# 29   CR-10846
# 30   CR-10815
# 31   CR-10819
# 32   CR-10828
# 33   CR-10845
# 34   CR-10817
# 35   CR-10844
# 36   CR-10816
# 37   CR-10829
# 38   CR-10839
# 39  R-SOPT-05
# 40   CR-10818

# %% [markdown]
# ##### *Raw Data*

# %%
raw0=fmun+folder+"\\3.1 Datos crudos"
raw2=pd.DataFrame(os.listdir(raw0))
print("Carpetas Raw Data");print(raw2)
listraw=[]
for raw1 in glob.iglob(raw0+"\\**\\**.*",recursive=True):
       
    lista0=raw1.split("\\3.1 Datos crudos\\")

    lista0=str(lista0[1])
    listraw.append(lista0)

listraw=[i.split('\\') for i in listraw]
raw=pd.DataFrame(listraw)
raw

puntosunicos1=raw.iloc[:,2].unique()  
print("Puntos: "+str(len(puntosunicos1)))
ptosunicos1=pd.DataFrame(puntosunicos1)
ptosunicos1
# Out:
# Carpetas Raw Data
#                  0
# 0   2023-03-13-072
# 1   2023-03-14-073
# 2   2023-03-15-074
# 3   2023-03-16-075
# 4   2023-03-17-076
# 5   2023-03-18-077
# 6   2023-03-20-079
# 7   2023-03-21-080
# 8   2023-03-22-081
# 9   2023-03-23-082
# 10  2023-03-25-084
# Puntos: 41
#             0
# 0    05761004
# 1    CR-10840
# 2   R-SOPT-01
# 3    CR-10811
# 4    CR-10820
# 5    CR-10821
# 6    CR-10823
# 7    CR-10832
# 8    CR-10841
# 9    CR-10824
# 10   CR-10825
# 11   CR-10837
# 12   CR-10838
# 13   CR-10842
# 14  R-SOPT-02
# 15  R-SOPT-06
# 16   CR-10810
# 17   CR-10826
# 18   CR-10827
# 19  R-SOPT-04
# 20   CR-10831
# 21   CR-10836
# 22  R-SOPT-03
# 23   CR-10813
# 24   CR-10833
# 25   CR-10834
# 26   CR-10835
# 27   CR-10847
# 28   CR-10830
# 29   CR-10846
# 30   CR-10815
# 31   CR-10819
# 32   CR-10828
# 33   CR-10845
# 34   CR-10817
# 35   CR-10844
# 36   CR-10816
# 37   CR-10829
# 38   CR-10839
# 39  R-SOPT-05
# 40   CR-10818

# %% [markdown]
# #### *Comparación carpetas Rinex y Raw Data*
# * *Carpetas por días*
#
# ###### *True=Cumple ~False=No cumple*

# %%
#comparación entre df Rinex y Raw

comparacion=rinexdf.isin(raw2.iloc[:,0])
comparacion
# Out:
#        0
# 0   True
# 1   True
# 2   True
# 3   True
# 4   True
# 5   True
# 6   True
# 7   True
# 8   True
# 9   True
# 10  True

# %% [markdown]
# #### *Comparación carpetas Rinex y Raw Data*
# * *Carpetas por puntos*

# %%
#comparacion entre subcarpetas
print("@@ --->Concidencia archivos Rinex y Raw Data")
comparacion1=ptosunicos.isin(ptosunicos1.iloc[:,0])
comparacion1
# Out:
# @@ --->Concidencia archivos Rinex y Raw Data
#        0
# 0   True
# 1   True
# 2   True
# 3   True
# 4   True
# 5   True
# 6   True
# 7   True
# 8   True
# 9   True
# 10  True
# 11  True
# 12  True
# 13  True
# 14  True
# 15  True
# 16  True
# 17  True
# 18  True
# 19  True
# 20  True
# 21  True
# 22  True
# 23  True
# 24  True
# 25  True
# 26  True
# 27  True
# 28  True
# 29  True
# 30  True
# 31  True
# 32  True
# 33  True
# 34  True
# 35  True
# 36  True
# 37  True
# 38  True
# 39  True
# 40  True

# %% [markdown]
# ### *Verificación Efemerides*

# %%
#Verificación Efemerides
fsp3=fmun+folder+"\\4. Efemerides precisas"
print( "$~---------> 4. Efemerides precisas")
for sp3 in glob.iglob(fsp3+"\\**\\**.*",recursive=True):
    print(sp3)
# Out:
# $~---------> 4. Efemerides precisas
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\4. Efemerides precisas\2023-03-13-072\IGS0OPSRAP_20230720000_01D_15M_ORB.SP3.gz
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\4. Efemerides precisas\2023-03-14-073\IGS0OPSRAP_20230730000_01D_15M_ORB.SP3.gz
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\4. Efemerides precisas\2023-03-15-074\IGS0OPSRAP_20230740000_01D_15M_ORB.SP3.gz
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\4. Efemerides precisas\2023-03-16-075\IGS0OPSRAP_20230750000_01D_15M_ORB.SP3.gz
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\4. Efemerides precisas\2023-03-17-076\IGS0OPSRAP_20230760000_01D_15M_ORB.SP3.gz
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\4. Efemerides precisas\2023-03-18-077\IGS0OPSRAP_20230770000_01D_15M_ORB.SP3.gz
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\4. Efemerides precisas\2023-03-20-079\IGS0OPSRAP_20230790000_01D_15M_ORB.SP3.gz
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\4. Efemerides precisas\2023-03-21-080\IGS0OPSRAP_20230800000_01D_15M_ORB.SP3.gz
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\4. Efemerides precisas\2023-03-22-081\IGS0OPSRAP_20230810000_01D_15M_ORB.SP3.gz
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\4. Efemerides precisas\2023-03-23-082\IGS0OPSRAP_20230820000_01D_15M_ORB.SP3.gz
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\4. Efemerides precisas\2023-03-25-084\GRG0OPSRAP_20230840000_01D_05M_ORB.SP3.gz

# %% [markdown]
# ### *Reportes de calculo*

# %%
fpdf=fmun+folder+"\\5. Reportes de calculo"
print(fpdf)
print( "$~---------> 5. Reportes de calculo")
for pdf in glob.iglob(fpdf+"\\**\\**.*",recursive=True):
    print(pdf.split("5. Reportes de calculo")[1])
# Out:
# D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Sopetran\Rural-Calidad\5. Reportes de calculo
# $~---------> 5. Reportes de calculo
# \Reporte\Base\Derivaciones de puntos.pdf
# \Reporte\Base\Informe de ajuste de red.pdf
# \Reporte\Base\Informe de procesamiento de líneas base.pdf
# \Reporte\Base\Lista de puntos.pdf
# \Reporte\Rover\Derivaciones de puntos.pdf
# \Reporte\Rover\Informe de ajuste de red.pdf
# \Reporte\Rover\Informe de procesamiento de líneas base.pdf
# \Reporte\Rover\Lista de puntos.pdf

# %% [markdown]
# ### *Registro Fotográfico*

# %%
#Verificación Registro Fotografico
foto=fmun+folder+"\\6. Registro Fotografico"
print( "$~---------> 6. Registro Fotografico")
foto0=os.listdir(foto)
print("@@ --->  Registro fotografico : "+str(len(foto0)))
foto0=pd.DataFrame(foto0);print(foto0);print("@---------> Detalle fotografias")
listfoto=[]
for foto in glob.iglob(foto+"\\**\\**.*",recursive=True):
    lista0=foto.split("\\6. Registro Fotografico\\")
    lista0=str(lista0[1])
    listfoto.append(lista0)

listfoto=[i.split('\\') for i in listfoto]
fotog=pd.DataFrame(listfoto)
fotog
# Out:
# $~---------> 6. Registro Fotografico
# @@ --->  Registro fotografico : 40
#             0
# 0    CR-10810
# 1    CR-10811
# 2    CR-10813
# 3    CR-10815
# 4    CR-10816
# 5    CR-10817
# 6    CR-10818
# 7    CR-10819
# 8    CR-10820
# 9    CR-10821
# 10   CR-10823
# 11   CR-10824
# 12   CR-10825
# 13   CR-10826
# 14   CR-10827
# 15   CR-10828
# 16   CR-10829
# 17   CR-10830
# 18   CR-10831
# 19   CR-10832
# 20   CR-10833
# 21   CR-10834
# 22   CR-10835
# 23   CR-10836
# 24   CR-10837
# 25   CR-10838
# 26   CR-10839
# 27   CR-10840
# 28   CR-10841
# 29   CR-10842
# 30   CR-10844
# 31   CR-10845
# 32   CR-10846
# 33   CR-10847
# 34  R-SOPT-01
# 35  R-SOPT-02
# 36  R-SOPT-03
# 37  R-SOPT-04
# 38  R-SOPT-05
# 39  R-SOPT-06
# @---------> Detalle fotografias
#              0                 1
# 0     CR-10810   CR-10810- E.jpg
# 1     CR-10810   CR-10810- N.jpg
# 2     CR-10810   CR-10810- P.jpg
# 3     CR-10810   CR-10810- S.jpg
# 4     CR-10810   CR-10810- W.jpg
# ..         ...               ...
# 239  R-SOPT-06  R-SOPT-06- N.jpg
# 240  R-SOPT-06  R-SOPT-06- P.jpg
# 241  R-SOPT-06  R-SOPT-06- S.jpg
# 242  R-SOPT-06  R-SOPT-06- W.jpg
# 243  R-SOPT-06         Thumbs.db
#
# [244 rows x 2 columns]

# %% [markdown]
# ### *Coordenadas*

# %% [markdown]
# ##### *Exportar XYZ data*

# %%
fcoor=fmun+folder+"\\7. Coordenadas"

for file in glob.iglob(fcoor+"\\*.xlsx",recursive=True):
    dfcoor=pd.read_excel(file,sheet_name='2018.0')
dfcoor=dfcoor.iloc[:,[0,3,4,6,7,8,9,10,11,12,14]]
dfcoor=dfcoor.drop(0)
dfcoor.columns=["NAME","Este","Norte","Latitud","Longitud","elipsoidal","X","Y","Z","Ortometrica","Altura_Elemento"]
dfcoor.to_csv(frev+"\\XYZ.csv",encoding="Latin-1",index=False)
dfcoor
# Out:
#          NAME         Este        Norte         Latitud         Longitud  \
# 1    CR-10810  4696550.505  2278912.365   6°31'0.23209"  75°44'40.95155"
# 2    CR-10811  4695328.885  2275790.047  6°29'18.41124"   75°45'20.1451"
# 3    CR-10813  4697207.995  2285563.405  6°34'36.78423"  75°44'20.73938"
# 4    CR-10815  4698431.722  2282432.376  6°32'55.11226"  75°43'40.36335"
# 5    CR-10816  4702052.339  2282322.255  6°32'52.16503"  75°41'42.53042"
# 6    CR-10817  4704856.914  2279648.873  6°31'25.65136"  75°40'10.80671"
# 7    CR-10818  4701149.399  2277424.264  6°30'12.61345"  75°42'11.05689"
# 8    CR-10819  4700746.419   2283398.27  6°33'26.95265"  75°42'25.21386"
# 9    CR-10820  4691010.494   2274091.05  6°28'22.35581"  75°47'40.33529"
Dcoor["D_Este"]=Dcoor["Este"]-Dcoor["ESTE"];Dcoor["D_Norte"]=Dcoor["Norte"]-Dcoor["NORTE"];Dcoor["D_Ortometrica"]=Dcoor["Ortometrica"]-Dcoor["Altura_Ort"]
Dcoor=Dcoor.iloc[:,[0,14,15,16]]
Dcoor
# Out:
#          NAME D_Este D_Norte  D_Ortometrica
# 0    CR-10810    0.0     0.0   0.000000e+00
# 1    CR-10811    0.0     0.0   0.000000e+00
# 2    CR-10813    0.0     0.0   0.000000e+00
# 3    CR-10815    0.0     0.0   0.000000e+00
# 4    CR-10816    0.0     0.0  -2.273737e-13
# 5    CR-10817    0.0     0.0  -4.547474e-13
# 6    CR-10818    0.0     0.0   0.000000e+00
# 7    CR-10819    0.0     0.0   0.000000e+00
# 8    CR-10820    0.0     0.0  -5.684342e-14
# 9    CR-10821    0.0     0.0   0.000000e+00
# 10   CR-10823    0.0     0.0   0.000000e+00
# 11   CR-10824    0.0     0.0   0.000000e+00
# 12   CR-10825    0.0     0.0   0.000000e+00
# 13   CR-10826    0.0     0.0   0.000000e+00
# 14   CR-10827    0.0     0.0   0.000000e+00
# 15   CR-10828    0.0     0.0   0.000000e+00
# 16   CR-10829    0.0     0.0  -4.547474e-13
# 17   CR-10830    0.0     0.0   1.136868e-13
# 18   CR-10831    0.0     0.0   0.000000e+00
# 19   CR-10832    0.0     0.0   5.684342e-14
# 20   CR-10833    0.0     0.0  -4.547474e-13
# 21   CR-10834    0.0     0.0  -2.273737e-13
# 22   CR-10835    0.0     0.0   0.000000e+00
# 23   CR-10836    0.0     0.0   5.684342e-14
# 24   CR-10837    0.0     0.0   0.000000e+00
# 25   CR-10838    0.0     0.0   0.000000e+00
# 26   CR-10839    0.0     0.0  -2.273737e-13
# 27   CR-10840    0.0     0.0   0.000000e+00
# 28   CR-10841    0.0     0.0   5.684342e-14
# 29   CR-10842    0.0     0.0   0.000000e+00
# 30   CR-10844    0.0     0.0   4.547474e-13
# 31   CR-10845    0.0     0.0   2.273737e-13
# 32   CR-10846    0.0     0.0   0.000000e+00
# 33   CR-10847    0.0     0.0   2.273737e-13
# 34  R-SOPT-01    0.0     0.0   0.000000e+00
# 35  R-SOPT-02    0.0     0.0   0.000000e+00
# 36  R-SOPT-03    0.0     0.0   4.547474e-13
# 37  R-SOPT-04    0.0     0.0  -2.273737e-13
# 38  R-SOPT-05    0.0     0.0   0.000000e+00
# 39  R-SOPT-06    0.0     0.0  -1.136868e-13

# %%
# prueba rinex -Leer antenas y alturas ** Falta ciclo para leer y compilar
# ruta=r"D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Abejorral\Urbano-Calidad\3. Datos rinex\2022-11-22-326\Rover\CU-0337\U3373268.22o"
# ruta=r"D:\PROYECTOS 2023\AEROESTUDIOS\INTERVENTORIA GNSS\Municipios\Abejorral\Urbano-Calidad\3. Datos rinex"

# for obs in glob.iglob(ruta+"\\**\\**.22o",recursive=True):
#     obs=obs.split(ruta)
#     obs=obs.split("\\")
#     print(obs)

# with open(ruta,"r") as archivo:
#     contenido=archivo.read()
# # print(contenido)
# filas=contenido.split("\n")
# dataf=pd.DataFrame(filas,columns=["colum"])
# dataf
